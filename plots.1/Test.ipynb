# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cl=np.load('XX_cl_dnu_py.npy')

# %%
cl.shape
# Out:
# (152, 7)

# %%
ell=cl[0,1:]

# %%
ell
# Out:
# array([ 724., 1123., 1529., 1939., 2344., 2761.])

# %%
cl=cl[1:,:]

# %%
for ii in range (len(ell)-1):
    plt.plot(cl[:,0],cl[:,ii+1]*1.e6,label='%d'%(ii+1))
#    plt.xscale('log')
#    plt.legend()
plt.show()

# %%
for ii in range (len(ell)):
    plt.plot(cl[1:,0],cl[1:,ii+1]*1.e6,label='%d'%(ii+1))
#    plt.xscale('log')
    plt.legend()
plt.show()

# %%
for ii in range (len(ell)):
    plt.plot(cl[1:,0],cl[1:,ii+1]*1.e6,label='%d'%(ii+1))
#    plt.xscale('log')
    plt.legend()
    plt.show()
